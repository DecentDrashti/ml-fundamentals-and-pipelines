# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>ML & DL</b></center>
#
# <center><b><h1>Drashti Ruparelia</b></center>
#
# <center><b><h1>Lab - 12</b></center>
# <pre>

# %% [markdown]
# ## Section 1: PyTorch

# %% [markdown]
# ## Import Torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
pip install torch

# %% [markdown]
# ### Task 1: GPU/Device Agnostic Code
# **Goal:** Write code that runs on CPU, CUDA, or MPS (Mac) automatically.

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f'Using device: {device}')


sample_input = torch.randn(1, 10).to(device)
type(sample_input)
# Out:
# Using device: cpu
# torch.Tensor

# %%
sample_input
# Out:
# tensor([[-0.1539,  1.4583, -0.4520,  0.9418,  1.1303, -1.4793, -1.2327, -0.9564,
#           1.1044, -0.9188]])

# %% [markdown]
# ## Section 2: MNIST Project
# Step 1: What is MNIST & Downloading Data
#
# Concept: MNIST is the "Hello World" of Machine Learning. It contains 70,000 images of handwritten digits (0-9).
#
# The Goal: Teach the computer to look at a grid of pixels and say "That is a 7".
#
# The Data: Each image is grayscale and exactly 28×28

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

# transform=ToTensor() converts the image (0-255) to a Torch Tensor (0.0-1.0)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %% [markdown]
# ## Visualizing One Image & Understanding Shapes

# %%
len(training_data)
# Out:
# 60000

# %%
len(test_data)
# Out:
# 10000

# %%
img, label = training_data[1000] #[0] for shoes

# %%
img.shape
# Out:
# torch.Size([1, 28, 28])

# %%
img

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## Display one Image in MatplotLib

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img.squeeze(), cmap="gray")
plt.title(f"This is a number {label}")
plt.show()

# %% [markdown]
# # Calculation for the Input Layer

# %% [markdown]
# Concept: We are building a Linear (Feed-Forward) Network,
#
# A Linear Layer consists of neurons in a single vertical line.
#
# Our image is a square grid (28×28).
#
# The Division: We must "cut" the image row by row and stack them into one long line.
#
# The Calculation:
#
# Height×Width=Total Input Features
# 28×28=784
# So, our Input Layer must have 784 neurons.

# %%
img, label = training_data[1]

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## The Architecture (1 Input, 1 Hidden, 1 Output
# The Concept: We will build the simplest standard network.
#
# Input Layer (784): Receives the pixels.
#
# Hidden Layer (128): The "brain" that learns shapes (loops, lines). We pick 128 because it's enough to learn but not too big.
#
# Output Layer (10): The final decision. We have 10 digits (0-9), so we need 10 output scores.

# %%
import torch.nn as nn

class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        
        self.layers = nn.Sequential(
            nn.Linear(784, 128), 
            nn.ReLU(),# Activation 
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.layers(x)
        return logits

model = SimpleNet()
print(model)
# Out:
# SimpleNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Understanding Batch Size (The Stack)
#
# The Concept: Think of the model like a teacher grading exams.
#
# Batch Size = 1: The teacher grades 1 exam, updates the grade book, then picks up the next exam. (Too slow).
#
# Batch Size = 64: The teacher picks up a stack of 64 exams, grades them all at once, and updates the grade book one time for the whole stack. (Much faster).
#
# We use DataLoader to create these "stacks" for us.

# %%
from torch.utils.data import DataLoader

# Create stacks
train_loader = DataLoader(training_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=True)

print(len(train_loader),"--",len(test_loader))
# Out:
# 938 -- 157

# %% [markdown]
# ## The Training Loop

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
def train():
    model.train()
    
    # Epoch Loop - Train for multiple epochs
    num_epochs = 5
    
    for epoch in range(num_epochs):
        print(f"\n--- Epoch {epoch + 1}/{num_epochs} ---")
        
        for batch_No, (data, target) in enumerate(train_loader):
            
            output = model(data)
            
            loss = loss_fn(output, target)
            
            # Backpropagation
            optimizer.zero_grad()  # Clear old calculations
            loss.backward()        # Calculate gradients
            optimizer.step()       # Update weights
            
            if batch_No % 100 == 0:
                print(f"Batch {batch_No}: Loss = {loss.item():.4f}")
        
        print(f"Epoch {epoch + 1} completed!")

# Run training

# %%
train()
# Out:
# --- Epoch 1/5 ---
# Batch 0: Loss = 2.2877
# Batch 100: Loss = 0.7400
# Batch 200: Loss = 0.7054
# Batch 300: Loss = 0.4557
# Batch 400: Loss = 0.5146
# Batch 500: Loss = 0.4280
# Batch 600: Loss = 0.3505
# Batch 700: Loss = 0.4882
# Batch 800: Loss = 0.6310
# Batch 900: Loss = 0.2655
# Epoch 1 completed!
#
# --- Epoch 2/5 ---
# Batch 0: Loss = 0.4169
# Batch 100: Loss = 0.5209
# Batch 200: Loss = 0.4703
# Batch 300: Loss = 0.4164
# Batch 400: Loss = 0.4778
# Batch 500: Loss = 0.2921
# Batch 600: Loss = 0.4038
# Batch 700: Loss = 0.4112
# Batch 800: Loss = 0.2683
# Batch 900: Loss = 0.4055
# Epoch 2 completed!
#
# --- Epoch 3/5 ---
# Batch 0: Loss = 0.4445
# Batch 100: Loss = 0.2387
# Batch 200: Loss = 0.3547
# Batch 300: Loss = 0.2717
# Batch 400: Loss = 0.4247
# Batch 500: Loss = 0.3136
# Batch 600: Loss = 0.4442
# Batch 700: Loss = 0.3659
# Batch 800: Loss = 0.3838
# Batch 900: Loss = 0.4032
# Epoch 3 completed!
#
# --- Epoch 4/5 ---
# Batch 0: Loss = 0.3539
# Batch 100: Loss = 0.3055
# Batch 200: Loss = 0.3005
# Batch 300: Loss = 0.4086
# Batch 400: Loss = 0.4216
# Batch 500: Loss = 0.2847
# Batch 600: Loss = 0.3312
# Batch 700: Loss = 0.4354
# Batch 800: Loss = 0.2807
# Batch 900: Loss = 0.2797
# Epoch 4 completed!
#
# --- Epoch 5/5 ---
# Batch 0: Loss = 0.2320
# Batch 100: Loss = 0.4653
# Batch 200: Loss = 0.2775
# Batch 300: Loss = 0.2656
# Batch 400: Loss = 0.3417
# Batch 500: Loss = 0.1916
# Batch 600: Loss = 0.3577
# Batch 700: Loss = 0.2593
# Batch 800: Loss = 0.2898
# Batch 900: Loss = 0.3397
# Epoch 5 completed!

# %%
def test():
    model.eval() 
    correct = 0
    
    with torch.no_grad(): 
        for data, target in test_loader:
            output = model(data)
            
            prediction = output.argmax(dim=1) 
            
            correct += (prediction == target).sum().item()

    accuracy = correct / len(test_loader.dataset)
    print(f"Test Accuracy: {accuracy:.1%}")

test()
# Out:
# Test Accuracy: 87.0%
